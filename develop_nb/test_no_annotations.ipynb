# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

import random

from phonetics import utils as u

# %%
root = '/Users/tomasandrade/Documents/BSC/ICHOIR/datasets/whale-sounds'

# %%
feat_files = glob.glob(f'{root}/feat/layer_12/*.csv')

# %%
df_not_ann = u.make_anotated_feat_df(feat_files, 
                                    None,
                                    tp_algn = None)
# Out:
# No type alignment provided
# -------- Finished making make_anotated_feat_df, time 0.9254720211029053

# %%
df_not_ann
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.105285  0.202863 -0.054312 -0.031539 -0.045452 -0.109686  0.049106
# 1     -0.178359  0.170509 -0.107578 -0.031091 -0.115149 -0.149219  0.010479
# 2     -0.192483  0.170795 -0.104062 -0.037707 -0.126536 -0.155641  0.005738
# 3     -0.294870  0.133599 -0.145530 -0.091920 -0.114541 -0.128358 -0.161514
# 4     -0.228620  0.002626 -0.210141 -0.106469  0.010999 -0.194088 -0.368091
# ...         ...       ...       ...       ...       ...       ...       ...
# 17153 -0.094832  0.282419 -0.097116  0.286634  0.067202  0.098599 -0.137928
# 17154 -0.005511  0.304990 -0.172940  0.258366  0.091819 -0.070633 -0.027238
# 17155 -0.114789  0.338516 -0.063429  0.253770 -0.081473  0.031057 -0.101410
# 17156 -0.081805  0.243173 -0.044573  0.301453 -0.243103  0.015924 -0.080399
# 17157 -0.006252  0.191878 -0.109930  0.392331 -0.106794  0.078947 -0.108534
#
# ...
