# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

# %%
import glob
import joblib
import pandas as pd
#from pathlib import Path
import matplotlib.pyplot as plt

from phonetics import utils as u
from phonetics import phone_info as ph_i 
from phonetics import plots as plots

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
root = '/Users/tomasandrade/Documents/BSC/ICHOIR/applio/Applio_LS/experiments'
experiment_path = f'{root}/gt_singer_EN_v0'
feat_2d_path = f'{experiment_path}/feat_2d/feat_2d_layer_12.csv'

# %%
df_anotated_2d = pd.read_csv(feat_2d_path, index_col=0)

# %%
len(df_anotated_2d['phone_base'].unique())
# Out:
# 40

# %%
plt.figure(figsize=(10,4))
df_anotated_2d['phone_base'].value_counts().plot.bar(rot = 45)
# Out:
# <Axes: xlabel='phone_base'>

# %%
len(df_anotated_2d['phone_base'])*0.02/60
# Out:
# 27.263333333333332

# %%
unique_phones = [k for k in df_anotated_2d['phone_base'].value_counts().keys() if k != '<SP>']

# %%
plots.make_tagged_LS_plot(df_anotated_2d,
            #phones = unique_phones[:5],
            phones = ['<SP>', '<AP>', 'S', 'M', 'N', 'L', 'R'],
            alpha = 0.25, 
            s = 0.3,
            show_global=True,
            xlim = [ -28, -15],
            ylim = [-45, -28])
# Out:
# Making a 2d plot
